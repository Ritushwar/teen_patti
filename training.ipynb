# %% [markdown]
# # CUSTOM TRAINING FOR POKER HAND DETECTION
# ## On Google Colab

# %%
# !nvidia-smi

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

# %% [markdown]
# ## USING CUSTOM TRAINING

# %%
# !yolo task=detect mode=train model=yolov8s.pt data="/content/drive/MyDrive/Object_detection/POKER_HAND_DETECTION/data.yaml" epochs=50 imgsz=640
# Out:
# ...
# Ultralytics 8.3.203 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...
